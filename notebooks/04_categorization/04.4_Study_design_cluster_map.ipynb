# %% [markdown]
# # Create 2D embedding-based cluster map to explore study designs

# %% [markdown]
# Analysis of articles and their study types
# - Set up libraries and datasets needed for figure creation
# - Creation of figures for study design overview
# - Creation of dynamic cluster map to explore articls and study types, based on semantic similarity
#
# ---> Need to open dynamic figure saved as HTML file in separate window!!

# %% [markdown]
# ## 1) Set up libraries and datasets

# %%
# Install necessary libraries
# !pip install umap-learn plotly scikit-learn tqdm --quiet
# !pip install sentence-transformers --quiet
# !pip install tf-keras
# !pip install --upgrade torch transformers sentence-transformers scikit-learn umap-learn plotly
print("Success!")

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
import torch
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import umap
from tqdm import tqdm
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px
import textwrap
from plotly.offline import init_notebook_mode, iplot

from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModel

pio.renderers.default = "notebook"
init_notebook_mode(connected=True)

print("Success!")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# Success!

# %%
from dotenv import load_dotenv

load_dotenv()  # loads variables from file .env

# Set the working directory and file paths
input_directory = '.'
output_directory = os.getenv("OUTPUT_DIRECTORY")
landscape_directory = os.getenv("LANDCSAPE_DIRECTORY")
classifier_directory = os.getenv("CLASSIFIER_DIRECTORY")

# Load dataset after classification
os.chdir(classifier_directory)
dataset_to_display="final_gc_classificaton_output_14498.csv"
stud_cat = pd.read_csv(dataset_to_display)
print("Success!")
print(stud_cat.head(3))
print("\nLength of dataset:", len(stud_cat))
# Out:
# Success!
#            Study_design Study Type  Probability     PaperId  \
# 0  In vivo/Animal study          -          NaN  7106250716
# 1        Clinical study          -          NaN  7125201640
# 2        In vitro study          -          NaN  7125263113
#
#                                           PaperTitle  \
# 0  PVNDMVLiver Circuit Drives Hepatocellular Carc...
# 1  Clinicopathological Factors on Survival after ...
# 2  SIAH2WNK1 Signaling Drives Glycolytic Metaboli...
#
#                                             Abstract
# 0  Hepatocellular carcinoma (HCC) and depression ...
# 1  Objective: To identify prognostic factors, inc...
# 2  Colorectal cancer (CRC) progression and therap...
#
# Length of dataset: 14498

# %% [markdown]
# ## 2) Create figure for study design overview

# %%
# Count occurrences of each study design
study_counts = stud_cat["Study_design"].value_counts()
total_count = study_counts.sum()
percentages = (study_counts / total_count * 100).round(2)
study_summary = pd.DataFrame({
    "Count": study_counts,
    "Percentage (%)": percentages
})
print("\nStudy Design Summary:")
print(study_summary)
print(f"\nTotal Study Designs Counted: {total_count}")

# Bar Chart of Study Design Types
plt.figure(figsize=(12, 6))
sns.barplot(x=study_counts.index, y=study_counts.values, palette="viridis")
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.xlabel("Study Design Type", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Distribution of Study Designs", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding percentage labels to the bar plot
for i, (count, percentage) in enumerate(zip(study_counts.values, percentages.values)):
    plt.text(i, count + 0.5, f'{percentage}%', ha='center', fontsize=10, fontweight='bold')
plt.show()

# Pie Chart of Study Design Types
plt.figure(figsize=(8, 8))
study_counts.plot.pie(autopct='%1.1f%%', startangle=140, cmap="tab10")
plt.title("Study Design Type Distribution", fontsize=14)
plt.ylabel("")  # Hide y-label
plt.show()

# Word Cloud Representation
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(study_counts)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Study Designs", fontsize=16)
plt.show()
# Out:
# Study Design Summary:
#                          Count  Percentage (%)
# Study_design
# In vitro study            4709           32.48
# Clinical study            2772           19.12
# In vivo/Animal study      2738           18.89
# Systematic review study   1430            9.86
# Observational/RWE study   1242            8.57
# Case report study          847            5.84
# In silico study            666            4.59
# undefined                   94            0.65
#
# Total Study Designs Counted: 14498
# /var/folders/57/yk3w62md44z9m6ndy61mkkz80000gn/T/ipykernel_10602/2632297239.py:15: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Analyze and visualize study design distribution
stud_cat["Study_design_clean"] = stud_cat["Study_design"].replace({"Behavioral study": "Other", "undefined": "Other"})
study_counts = stud_cat["Study_design_clean"].value_counts()
total_count = study_counts.sum()
percentages = (study_counts / total_count * 100).round(2)
study_summary = pd.DataFrame({"Count": study_counts, "Percentage (%)": percentages})
print("\nStudy Design Summary:")
print(study_summary)
print(f"\nTotal Study Designs Counted: {total_count}")

# Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x=study_counts.index, y=study_counts.values, palette="viridis")
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.xlabel("Study Design Type", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Distribution of Study Designs", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)
for i, (count, percentage) in enumerate(zip(study_counts.values, percentages.values)):
    plt.text(i, count + 0.5, f'{percentage}%', ha='center', fontsize=10, fontweight='bold')
plt.tight_layout()
plt.show()

# Pie Chart
plt.figure(figsize=(8, 8))
study_counts.plot.pie(autopct='%1.1f%%', startangle=140, cmap="tab10")
plt.title("Study Design Type Distribution", fontsize=14)
plt.ylabel("")
plt.tight_layout()
plt.show()

# Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(study_counts)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Study Designs", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Study Design Summary:
#                          Count  Percentage (%)
# Study_design_clean
# In vitro study            4709           32.48
# Clinical study            2772           19.12
# In vivo/Animal study      2738           18.89
# Systematic review study   1430            9.86
# Observational/RWE study   1242            8.57
# Case report study          847            5.84
# In silico study            666            4.59
# Other                       94            0.65
#
# Total Study Designs Counted: 14498
# /var/folders/57/yk3w62md44z9m6ndy61mkkz80000gn/T/ipykernel_10602/2117103787.py:13: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
#  ## 3) Create 2D embedding-based cluster map

# %%
full_df.columns # PubYear missing! (Update-AB)
# Out:
# Index(['Study_design', 'Study Type', 'Probability', 'PaperId', 'PaperTitle',
#        'Abstract', 'Study_design_clean'],
#       dtype='str')

# %%
# Validate study design dataset, check missing values, and filter empty entries
full_df = stud_cat.copy()
print("Length of dataset:", len(full_df))
#expected_columns = ["PaperTitle", "Abstract", "PubYear", "Study_design"] # Update-AB: try to remove PubYear to debug
expected_columns = ["PaperTitle", "Abstract", "Study_design"]
if not all(col in full_df.columns for col in expected_columns):
    raise ValueError(f"Missing expected columns. Ensure the dataset has: {expected_columns}")
print("Success!")


empty_papertitle = full_df["PaperTitle"].isna().sum() + (full_df["PaperTitle"].str.strip() == "").sum()
empty_abstract = full_df["Abstract"].isna().sum() + (full_df["Abstract"].str.strip() == "").sum()
empty_study_design = full_df["Study_design"].isna().sum() + (full_df["Study_design"].str.strip() == "").sum()
print(f"\nTotal rows: {len(full_df)}")
print(f"Empty PaperTitle rows: {empty_papertitle}")
print(f"Empty Abstract rows: {empty_abstract}")
print(f"Empty Study_design rows: {empty_study_design}")
missing_study_design_df = full_df[full_df["Study_design"].isna() | (full_df["Study_design"].str.strip() == "")]
filtered_full_df = full_df.dropna(subset=["Study_design"])
filtered_full_df = filtered_full_df[filtered_full_df["Study_design"].str.strip() != ""]


print(f"\nOriginal dataset length: {len(full_df):,}")
print(f"Rows with empty Study_design removed: {len(missing_study_design_df):,}")
print(f"Filtered dataset length: {len(filtered_full_df):,}")
full_df = stud_cat.copy()
# Out:
# Length of dataset: 14498
# Success!
#
# Total rows: 14498
# Empty PaperTitle rows: 0
# Empty Abstract rows: 0
# Empty Study_design rows: 0
#
# Original dataset length: 14,498
# Rows with empty Study_design removed: 0
# Filtered dataset length: 14,498

# %%
# Normalize study design dataset, merge categories, check missing values, and filter

full_df = stud_cat.copy()
print("Length of dataset:", len(full_df))

#expected_columns = ["PaperTitle", "Abstract", "PubYear", "Study_design"] # Update-AB: try to remove PubYear to debug
expected_columns = ["PaperTitle", "Abstract", "Study_design"]
if not all(col in full_df.columns for col in expected_columns):
    raise ValueError(f"Missing expected columns. Ensure the dataset has: {expected_columns}")
print("Success!")
full_df["Study_design_clean"] = full_df["Study_design"].replace({"Behavioral study": "Other", "undefined": "Other"})
empty_papertitle = full_df["PaperTitle"].isna().sum() + (full_df["PaperTitle"].str.strip() == "").sum()
empty_abstract = full_df["Abstract"].isna().sum() + (full_df["Abstract"].str.strip() == "").sum()
empty_study_design = full_df["Study_design_clean"].isna().sum() + (full_df["Study_design_clean"].str.strip() == "").sum()

print(f"\nTotal rows: {len(full_df)}")
print(f"Empty PaperTitle rows: {empty_papertitle}")
print(f"Empty Abstract rows: {empty_abstract}")
print(f"Empty Study_design rows: {empty_study_design}")

missing_study_design_df = full_df[full_df["Study_design_clean"].isna() | (full_df["Study_design_clean"].str.strip() == "")]
filtered_full_df = full_df.dropna(subset=["Study_design_clean"])
filtered_full_df = filtered_full_df[filtered_full_df["Study_design_clean"].str.strip() != ""]
print(f"\nOriginal dataset length: {len(full_df):,}")
print(f"Rows with empty Study_design removed: {len(missing_study_design_df):,}")
print(f"Filtered dataset length: {len(filtered_full_df):,}")
# Out:
# Length of dataset: 14498
# Success!
#
# Total rows: 14498
# Empty PaperTitle rows: 0
# Empty Abstract rows: 0
# Empty Study_design rows: 0
#
# Original dataset length: 14,498
# Rows with empty Study_design removed: 0
# Filtered dataset length: 14,498

# %%
# Load SciBERT model & tokenizer correctly (takes about 4h for 200k articles)
hf_token = os.getenv("HUGGINGFACE_TOKEN") #"YOUR_HFTOKEN" #replace with token
model_name = "allenai/scibert_scivocab_uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name, token=hf_token)
model = AutoModel.from_pretrained(model_name, token=hf_token)


# Function to compute embeddings
def get_sci_bert_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# Apply SciBERT to abstracts
print("Generating SciBERT embeddings for", len(full_df), "for articles ...")
#embeddings = np.array([get_sci_bert_embedding(text) for text in tqdm(full_df["Abstract"])])
embeddings = np.array([
    get_sci_bert_embedding(str(text)) if isinstance(text, str) else get_sci_bert_embedding("")
    for text in tqdm(full_df["Abstract"].fillna(""))
])


# UMAP Dimensionality Reduction
import umap
print("Applying UMAP dimensionality reduction...")
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='cosine')
embedding_2d = umap_model.fit_transform(embeddings)

# Ensure the UMAP output matches the dataframe size
if len(embedding_2d) != len(full_df):
    raise ValueError(f"Mismatch: UMAP produced {len(embedding_2d)} embeddings, but dataframe has {len(full_df)} rows.")

# Add UMAP results to DataFrame
full_df["UMAP_1"] = embedding_2d[:, 0]
full_df["UMAP_2"] = embedding_2d[:, 1]

print("Success!")
# Out:
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Generating SciBERT embeddings for 14498 for articles ...
#   0%|          | 7/14498 [00:00<22:38, 10.67it/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# 100%|██████████| 14498/14498 [22:06<00:00, 10.93it/s]
# Applying UMAP dimensionality reduction...
# Success!

# %%
# Save full DataFrame with UMAP results
os.chdir(landscape_directory) # Update-AB: added
output_filename = "full_df_with_umap_for_scatter_plot.csv"
full_df.to_csv(output_filename, index=False)
print(f"Processed DataFrame saved as: {output_filename}")

# Save UMAP reduced embeddings
umap_embedding_filename = "umap_embeddings_for_scatter_plot.npy"
np.save(umap_embedding_filename, embedding_2d)
print(f"UMAP embeddings saved as: {umap_embedding_filename}")

# Save SciBERT embeddings (optional)
scibert_embedding_filename = "scibert_embeddings_for_scatter_plot.npy"
np.save(scibert_embedding_filename, embeddings)
print(f"SciBERT embeddings saved as: {scibert_embedding_filename}")

# Save the interactive plot as an HTML file
html_file_path = "Interactive_UMAP_Scatter_Plot_Study_Designs.html"
Study_Type_plot.write_html(html_file_path) # Update-AB: variable Study_Type_plot don't exist here! Initialized two cells later
print(f"Interactive scatter plot saved as: {html_file_path}")
# Out:
# Processed DataFrame saved as: full_df_with_umap_for_scatter_plot.csv
# UMAP embeddings saved as: umap_embeddings_for_scatter_plot.npy
# SciBERT embeddings saved as: scibert_embeddings_for_scatter_plot.npy
# Interactive scatter plot saved as: Interactive_UMAP_Scatter_Plot_Study_Designs.html

# %%
print(full_df.head(5))
print(f"\nLength of dataset: {len(full_df):,}")
# Out:
#            Study_design Study Type  Probability     PaperId  \
# 0  In vivo/Animal study          -          NaN  7106250716
# 1        Clinical study          -          NaN  7125201640
# 2        In vitro study          -          NaN  7125263113
# 3  In vivo/Animal study          -          NaN  7124882620
# 4        In vitro study          -          NaN  7124922374
#
#                                           PaperTitle  \
# 0  PVNDMVLiver Circuit Drives Hepatocellular Carc...
# 1  Clinicopathological Factors on Survival after ...
# 2  SIAH2WNK1 Signaling Drives Glycolytic Metaboli...
# 3  B021: Modeling Human Immune Competent Patient-...
# 4  Evaluation of agmatines anti-cancer efficacy i...
#
#                                             Abstract    Study_design_clean  \
# 0  Hepatocellular carcinoma (HCC) and depression ...  In vivo/Animal study
# 1  Objective: To identify prognostic factors, inc...        Clinical study
# 2  Colorectal cancer (CRC) progression and therap...        In vitro study
# 3  Background: As the most common non-cutaneous f...  In vivo/Animal study
# 4  This study aimed to evaluate the potential eff...        In vitro study
#
#      UMAP_1    UMAP_2
# 0  6.646993  2.826766
# 1  8.642829  8.452847
# 2  6.559774  3.496231
# 3  8.633031  2.672034
# 4  5.969605  0.547263
#
# Length of dataset: 14,498

# %%
# Create interactive UMAP scatter plot of study designs based on abstract similarity

pio.renderers.default = "notebook_connected"
os.chdir(landscape_directory)
csv_file_path = "full_df_with_umap_for_scatter_plot.csv"
figure_df = pd.read_csv(csv_file_path)
print(f"Loaded DataFrame with {len(figure_df)} rows from {csv_file_path}")

figure_df["Study_design_clean"] = figure_df["Study_design"].replace({"Behavioral study": "Other", "undefined": "Other"})
scale_factor = 2.5
colorpalette = px.colors.qualitative.Plotly
Study_Type_plot = px.scatter(
    figure_df,
    x="UMAP_1",
    y="UMAP_2",
    color="Study_design_clean",
    hover_data={"PaperTitle": True}, #{"PaperTitle": True, "PubYear": True}, Update-AB: removed PubYera
    title=f"Study designs based on abstract similarity (n={len(figure_df)} articles)",
    labels={"UMAP_1": "UMAP_1", "UMAP_2": "UMAP_2", "Study_design_clean": "Study design"},
    template="plotly_white",
    opacity=0.7,
    color_discrete_sequence=colorpalette
)

Study_Type_plot.update_layout(
    width=int(800 * scale_factor),
    height=int(400 * scale_factor),
    font=dict(size=int(12 * scale_factor)),
    title_font=dict(size=int(16 * scale_factor)),
    legend=dict(title="Study design", font=dict(size=int(10 * scale_factor))),
    hoverlabel=dict(font_size=int(12 * scale_factor), font_family="Arial", bgcolor="white", bordercolor="black", align="left"),
    hovermode="closest"
)

for trace in Study_Type_plot.data:
    if 'marker' in trace:
        trace.marker.size = int(2)
unique_study_types = figure_df["Study_design_clean"].unique()
legend_markers = []
for i, study_type in enumerate(unique_study_types):
    legend_markers.append(go.Scatter(
        x=[None], y=[None],
        mode="markers",
        marker=dict(size=15, color=colorpalette[i % len(colorpalette)], line=dict(width=2, color="black")),
        name=study_type,
        legendgroup="Study design",
        showlegend=True
    ))

for trace in Study_Type_plot.data:
    trace.showlegend = False
for marker in legend_markers:
    Study_Type_plot.add_trace(marker)
html_file_path = "Interactive_scatter_plot_study_design_type_plot.html"
Study_Type_plot.write_html(html_file_path)

print("Open the saved HTML file to see the improved visualization with restored colors.")
print(f"Saved figure: {html_file_path}")
# Out:
# Loaded DataFrame with 14498 rows from full_df_with_umap_for_scatter_plot.csv
# Open the saved HTML file to see the improved visualization with restored colors.
# Saved figure: Interactive_scatter_plot_study_design_type_plot.html

# %%
# Investigate outliers
csv_file_path = "full_df_with_umap_for_scatter_plot.csv" 
figure_df = pd.read_csv(csv_file_path)

outliers_df = figure_df[(figure_df["UMAP_1"] < 2) | (figure_df["UMAP_1"] > 17) | (figure_df["UMAP_2"] < -5) |(figure_df["UMAP_2"] > 10)]

cleaned_figure_df = figure_df.drop(outliers_df.index)
print("Length of cleaned dataset: {:,}".format(len(cleaned_figure_df)))

pd.set_option("display.max_rows", 400) 
print("\n\n\nLength of outliers: {:,}".format(len(outliers_df)))
print(outliers_df)
# 1249   Introduction: Pancreatic cancer stands as the ...
# 1270   Human Werner syndrome (adult progeria, a well-...
# 1493   Colorectal cancer (CRC) is a type of gastroint...
# 1604   Exosomal microRNAs (miRNAs) serve as dependabl...
# 1607   MicroRNA (miRNA) is involved in the genesis in...
# 1683   The detection of disease-related protein bioma...
# 1791   Background: Pulmonary neuroendocrine tumors (N...
# 1804   Acute myeloid leukemia (AML) is an aggressive ...
# 1832   Deciphering and analyzing the signaling pathwa...
# 1872   MicroRNAs (miRNAs) are key regulators of disea...
# 1969   Pancreatic ductal adenocarcinoma (PDAC) remain...
# 1971   Proteus syndrome is a rare mosaic overgrowth d...
# 1992   Rapid, accurate, and renewable electrochemilum...
# 2166   Introduction/Objective EWSR1 rearranged sarcom...
# 2170   Introduction/Objective Adenoid cystic carcinom...
# 2177   Low-grade fibromyxoid tumors are extremely rar...
# 2460   MicroRNAs are closely associated with various ...
# 2609   Liquid biopsy is a transformative, noninvasive...
# 2659   MicroRNA (miRNA) is a noncoding RNA that regul...
# 2662   This talk will focus on the potential of optic...
# 2683   Background/Objectives: Carbohydrate antigen 19...
# 2737   In this study, a multifunctional tetrahedral D...
# 2822   Cholangiocarcinoma (CCA) is a diverse collecti...
# 2845   Intracranial mesenchymal tumors with female ex...
# 2965   Early detection of pancreatic cancer is vital ...
# 2966   Flash-type chemiluminescence (CL) systems are ...
# 2968   Analysis of multiple surface proteins on extra...
# 3001   Caspase-3 is a pivotal enzyme in the apoptosis...
# 3207   Primary effusion lymphoma (PEL) is a rare and ...
# 3225   Therapeutic drug monitoring is essential for o...
# 3283   Extracellular vesicles (EVs) are highly attrac...
# 3378   Personalized monitoring of disease biomarkers ...
# 3439   4-Aminobiphenyl (4-ABP) is a known human carci...
# 3511   Exosomal microRNAs (miRNAs) are among the most...
# 3547   Volatile organic compounds (VOCs) serve as cri...
# 3695   BRCA1-associated protein (BAP1)-inactivated me...
# 3707   Approximately 30% of stage II and 70% of stage...
# 3769   Introduction Lung cancer prevalence rate has b...
# 3770   The nondestructive capture and direct identifi...
# 3816   Longitudinal monitoring of therapeutic respons...
# 3833   Electrochemical immunosensors are emerging as ...
# 3857   Background This report presents an exceptional...
# 3885   Breast cancer remains one of the leading cause...
# 3924   Digital assays are in wide development for bio...
# 3978   Introduction/Objective Composite lung cancers,...
# 3982   Introduction/Objective Insulinoma-associated p...
# 4042   Perivascular epithelioid cell tumors (PEComas)...
# 4055   The development of DNA logic circuits has enab...
# 4126   Background Synovial sarcoma is a rare malignan...
# 4214   Background and Clinical Significance: Mucinous...
# 4416   Precision chemotherapy management requires eff...
# 4497   Overcoming the critical limitation of poor sen...
# 4551   In this study, a multifunctional tetrahedral D...
# 4570   Breast cancer is a leading cause of cancer-rel...
# 4635   Cholangiocarcinoma (CCA) is a diverse collecti...
# 4693   e13038 Background: Circulating tumor cells (CT...
# 4894   Human Werner syndrome (adult progeria, a well-...
# 4895   Human Werner syndrome (adult progeria, a well-...
# 5041   The target neutrophil-activating peptide-2, NA...
# 5251   Plasmablastic lymphoma (PBL) is an aggressive ...
# 5255   Bladder cancer diagnosis typically involves ap...
# 5315   Dermatofibrosarcoma protuberans (DFSP) is an i...
# 5325   CRISPR/Cas 12a system based nucleic acid and n...
# 5333   Accurate identification and quantification of ...
# 5343   Uterine tumor resembling ovarian sex cord tumo...
# 5432   Pancreatic cancer is one of the deadliest canc...
# 5509   Chromophobe thyroid carcinoma (CTC) is a rare ...
# 5590   Purpose Ocular involvement is exceedingly unco...
# 5631   Persistent exposure to highrisk human papillom...
# 5791   Introduction/Objective The cholangioblastic va...
# 5794   Introduction/Objective Secretory carcinoma (SC...
# 6152   Development of nanozymes with enhanced activit...
# 6229   Precision chemotherapy management requires eff...
# 6314   The use of microRNAs as clinical cancer biomar...
# 6436   The screening and monitoring of microRNAs as c...
# 6447   Cholangiocarcinoma (CCA) is a diverse collecti...
# 6586   Nucleic acids can form diverse non-canonical s...
# 6634   We have developed a platform for the multiplex...
# 6706   Human Werner syndrome (adult progeria, a well-...
# 6707   Human Werner syndrome (adult progeria, a well-...
# 6850   The target neutrophil-activating peptide-2, NA...
# 6864   Simultaneous analysis of multiple biomarkers c...
# 6877   Breast cancer is the most prevalent malignancy...
# 6922   The logic profiling of exosomal microRNAs (miR...
# 6944   Plasmacytoid urothelial carcinoma is a rare bu...
# 7066   Breast cancer1-associated protein 1 (BAP-1)-in...
# 7068   Colorectal cancer (CRC) is one of the most tre...
# 7100   5-Methylcytosine (5mC) and 5-hydroxymethylcyto...
# 7380   Given the low abundance of circulating miRNAs ...
# 7397   Spitz melanocytoma is a melanocytic neoplasm o...
# 7399   The nondestructive capture and direct identifi...
# 7417   Tall cell carcinoma of the breast with reverse...
# 7467   A 43-year-old man with sigmoid colon adenocarc...
# 7602   Introduction/Objective Endolymphatic sac tumor...
# 7603   Introduction/Objective The DNAJB1-PRKACA fusio...
# 7607   Introduction/Objective Schwannomas are benign ...
# 7763   Intra-abdominal epithelioid neoplasm with EWSR...
# 7780   Epithelioid hemangioma (EH) of the liver is an...
# 8042   Liquid biopsy is a transformative, noninvasive...
# 8108   RNA in small extracellular vesicles (sEVs) fro...
# 8318   HPV16 identification is crucial for pointofcar...
# 8411   Solid papillary carcinoma (SPC) is rare, accou...
# 8519   Human Werner syndrome (adult progeria, a well-...
# 8784   Engrailed-2 (EN2) protein, a transcription fac...
# 8794   Interleukin-6 (IL-6) is a common proinflammato...
# 8927   The rapid, simple, and sensitive detection of ...
# 9073   Background Adenoid cystic carcinoma (ACC), als...
# 9081   Breast cancer remains a leading cause of morta...
# 9194   Given the low abundance of circulating miRNAs ...
# 9232   The early diagnosis of hepatocellular carcinom...
# 9340   The simultaneous detection of multiple cancer ...
# 9414   Introduction/Objective Cardiac tumors are rare...
# 9415   Introduction/Objective Metaplastic carcinoma i...
# 9419   Introduction/Objective Chordomas are tumors de...
# 9587   OBJECTIVE Erdheim Chester disease (ECD) is a r...
# 9637   Human SNU cell lines, derived from hepatocellu...
# 9664   Granular Cell Tumour (GCT) of the breast is a ...
# 9748   miRNAs regulate cancer progression and serve a...
# 9775   Photoelectrochemical (PEC) immunosensors have ...
# 9804   Continued development of high-performance, low...
# 9806   Background The histone chaperone complex, cons...
# 9835   Since carbohydrate antigen 19-9 (CA 19-9) is a...
# 9852   Pancreatic extra-gastrointestinal stromal tumo...
# 9881   RNA N 6 methyladenosine (m 6 A) modification p...
# 9914   Indoleamine 2,3-dioxygenase 1 (IDO-1) and inte...
# 10072  Cholangiocarcinoma (CCA) is a diverse collecti...
# 10195  Proteases secreted by tumor cells have been em...
# 10331  Human Werner syndrome (adult progeria, a well-...
# 10486  Simultaneous analysis of multiple biomarkers c...
# 10510  Since epidermal growth factor receptor (EGFR) ...
# 10531  Oral cancer presents substantial challenges to...
# 10596  Proteins can act as suitable biomarkers for th...
# 10728  This study presents a novel electrochemical bi...
# 10744  Lung cancer is a devastating public health thr...
# 11054  Rapid, accurate, and renewable electrochemilum...
# 11056  Immune checkpoint inhibitors (ICIs), particula...
# 11109  Developing innovative chip-based sensors with ...
# 11154  Early and accurate detection of multiple micro...
# 11230  Introduction/Objective Hemangioblastomas (HBs)...
# 11469  Exosomal miRNA-21 has emerged as a promising b...
# 11470  Exosomal miRNA-21 has emerged as a promising b...
# 11536  This research work presents an innovative char...
# 11588  Development of nanozymes with enhanced activit...
# 11654  Extrachromosomal circular DNA (eccDNA) has eme...
# 11658  Extrachromosomal circular DNA (eccDNA) has eme...
# 11703  Massive/mass-forming ductular reaction of the ...
# 11884  Cholangiocarcinoma (CCA) is a diverse collecti...
# 11887  Liquid biopsy has emerged as a promising non-i...
# 12008  Proteases secreted by tumor cells have been em...
# 12009  Saliva is a noninvasive, easily collected flui...
# 12027  Analysis of multiple surface proteins on extra...
# 12076  Glycoproteins are produced by glycosylation mo...
# 12143  Human Werner syndrome (adult progeria, a well-...
# 12367  Cellular traction force measurement has been u...
# 12393  Colorectal cancer (CRC) begins in the innermos...
# 12515  An ultrasensitive and label-free electrochemic...
# 12591  ENPP-1 is a transmembrane enzyme involved in n...
# 12662  Sinonasal teratocarcinosarcoma (SNTCS) represe...
# 12682  The search for new technologies to reliably de...
# 12828  The programmability and flexibility of the RNA...
# 12922  Developing innovative chip-based sensors with ...
# 12954  Background: Lung cancer is the second most com...
# 13037  Introduction/Objective Burkitt Lymphoma is an ...
# 13039  Introduction/Objective Malignant mesothelioma ...
# 13042  Introduction/Objective While metastatic carcin...
# 13424  Continued development of high-performance, low...
# 13532  In clinical applications of surface-enhanced R...
# 13696  Cholangiocarcinoma (CCA) is a diverse collecti...
# 13715  BCOR-altered sarcomas (BAS) are a subset of un...
# 13839  8-17 DNAzyme is a well-known versatile nucleic...
# 13870  Caspase-3 is a pivotal enzyme in the apoptosis...
# 13930  Synovial sarcoma (SS) is a tumor of uncertain ...
# 13952  Human Werner syndrome (adult progeria, a well-...
# 13955  Human Werner syndrome (adult progeria, a well-...
# 14081  The 2024 Nobel Prize in Physiology or Medicine...
# 9804         In vitro study  1.668241   2.530215
# 9806         In vitro study  9.495868  -6.026578
# 9835         In vitro study  1.626882   2.494693
# 9852      Case report study  3.669210  10.035882
# 9881         In vitro study  1.853910   2.743721
# 9914         In vitro study  1.648536   2.498848
# 10072        In vitro study  9.495950  -6.030435
# 10195        In vitro study  1.881237   2.629920
# 10331  In vivo/Animal study -7.188744   5.807157
# 10486        In vitro study  1.924469   2.603838
# 10510     Case report study  3.760848  10.003706
# 10531        In vitro study  1.670940   2.557507
# 10596        In vitro study  1.703243   2.561719
# 10728        In vitro study  1.741367   2.576718
# 10744        In vitro study  1.652620   2.484101
# 11054        In vitro study  1.880954   2.699746
# 11056     Case report study  3.454292  10.082624
# 11109        In vitro study  1.581381   2.441409
# 11154        In vitro study  1.775150   2.615765
# 11230     Case report study  3.500576  10.142445
# 11469        In vitro study  1.885391   2.703939
# 11470        In vitro study  1.886490   2.706328
# 11536       In silico study  1.654153   2.518013
# 11588        In vitro study  1.625302   2.490292
# 11654        In vitro study  1.908845   2.712961
# 11658        In vitro study  1.911325   2.719866
# 11703     Case report study  3.642538  10.001264
# 11884        In vitro study  9.495958  -6.030417
# 11887        In vitro study  1.780954   2.625901
# 12008        In vitro study  1.881207   2.629593
# 12009        In vitro study  1.732307   2.586166
# 12027        In vitro study  1.886823   2.703204
# 12076        In vitro study  1.634506   2.509967
# 12143  In vivo/Animal study -7.188856   5.807160
# 12367        In vitro study  1.951153   2.660048
# 12393        In vitro study  1.680208   2.525740
# 12515        In vitro study  1.677068   2.542208
# 12591        In vitro study  1.906058   2.315189
# 12662     Case report study  3.612966  10.053917
# 12682        In vitro study  1.972999   2.791613
# 12828        In vitro study  1.908989   2.728597
# 12922        In vitro study  1.635409   2.490164
# 12954        In vitro study  1.705890   2.559791
# 13037     Case report study  3.464403  10.124191
# 13039     Case report study  3.558498  10.096210
# 13042     Case report study  3.440262  10.074203
# 13424        In vitro study  1.598243   2.465236
# 13532        In vitro study  1.691408   2.530906
# 13696        In vitro study  9.496090  -6.030717
# 13715     Case report study  3.503308  10.033512
# 13839        In vitro study  1.779930   2.626745
# 13870        In vitro study  1.924378   2.388905
# 13930     Case report study  3.641319  10.154024
# 13952  In vivo/Animal study -7.188906   5.807167
# 13955  In vivo/Animal study -7.188933   5.807169
# 14081        In vitro study  1.819970   2.636774
# 14123        In vitro study  1.723766   2.555428
# 14134        In vitro study  1.965363   2.683569
# 14273        In vitro study  1.865933   2.662543
# 14467     Case report study  3.418266  10.066271

# %%
# Prepare data
os.chdir(landscape_directory)
figure_df = cleaned_figure_df.copy()
figure_df["Study_design_clean"] = figure_df["Study_design"].replace({
    "Behavioral study": "Other", "undefined": "Other"
})
print(f"Using cleaned DataFrame with {len(figure_df)} rows.")

# Wrap long paper titles for better hover display
def wrap_text(text, width=60):
    return "<br>".join(textwrap.wrap(text, width=width))

figure_df["PaperTitle_wrapped"] = figure_df["PaperTitle"].apply(lambda t: wrap_text(t, width=60))
scale_factor = 2.5
colorpalette = px.colors.qualitative.Plotly

color_map = {
    "In vitro study": "#0072B2",   # bold blue
    "Clinical study": "#00BFC4",   # cyan
    "Systematic review study": "#00BE67",  # bright green
    "In vivo/Animal study": "#F9E300",  # vibrant yellow
    "In silico study": "#FF6F00",  # bold orange
    "Case report study": "#C7107E",  # vivid magenta
    "Observational/RWE study": "#A200FF",  # bright purple
    "Other": "#7F7F7F",  # medium gray (neutral)
}


unique_study_types = list(color_map.keys())

Study_Type_plot = go.Figure()
for study_type in unique_study_types:
    group_df = figure_df[figure_df["Study_design_clean"] == study_type]
    color = color_map[study_type]

    Study_Type_plot.add_trace(go.Scatter(
        x=group_df["UMAP_1"],
        y=group_df["UMAP_2"],
        mode="markers",
        name=study_type,
        marker=dict(size=2, color=color),
        customdata=group_df[["Study_design_clean", "UMAP_1", "UMAP_2", "PaperTitle_wrapped"]], #, "PubYear"]],
        hovertemplate=(
            "<b>Study design:</b> %{customdata[0]}<br>" +
            "<b>UMAP_1:</b> %{customdata[1]:.2f}<br>" +
            "<b>UMAP_2:</b> %{customdata[2]:.2f}<br>" +
            "<b>Paper title:</b><br>%{customdata[3]}<br>" +
            "<b>Publication year:</b> %{customdata[4]}<extra></extra>"
        ),
        hoverlabel=dict(
            bgcolor=color,
            font=dict(family="Arial", size=int(12 * scale_factor)),
            bordercolor="black",
            align="left"
        ),
        showlegend=False
    ))

legend_markers = []
for study_type in unique_study_types:
    legend_markers.append(go.Scatter(
        x=[None], y=[None],
        mode="markers",
        marker=dict(size=15, color=color_map[study_type], line=dict(width=2, color="black")),
        name=study_type,
        legendgroup="Study design",
        showlegend=True
    ))

for marker in legend_markers:
    Study_Type_plot.add_trace(marker)

Study_Type_plot.update_layout(
    width=int(800 * scale_factor),
    height=int(600 * scale_factor),  
    font=dict(family="Arial", size=int(12 * scale_factor)),
    legend=dict(
        title="Study design",
        font=dict(family="Arial", size=int(10 * scale_factor))
    ),
    hovermode="closest",
    template="plotly_white",
    xaxis_title="UMAP dimension 1",
    yaxis_title="UMAP dimension 2",
    margin=dict(t=550, b=100)  
)


Study_Type_plot.add_annotation(
    text=f"Study designs based on abstract similarity (n={len(figure_df)} articles)",
    xref="paper", yref="paper",
    x=0.5, y=1.3, 
    showarrow=False,
    font=dict(family="Arial", size=int(16 * scale_factor), color="#1f2c56"),
    xanchor="center"
)

Study_Type_plot.add_annotation(
    text=(
        "This UMAP projection uses SciBERT-derived abstract embeddings to position articles by semantic similarity.<br>"
        "Study design types were automatically classified using LLaMA 3.3-70B.<br>"
    ),
    xref="paper", yref="paper",
    x=0.5, y=1.17,  
    showarrow=False,
    align="center",
    font=dict(family="Arial", size=int(12 * scale_factor), color="#1f2c56"),
    xanchor="center"
)

html_file_path = "Interactive_cluster_map_study_design_type_plot_final.html"
Study_Type_plot.write_html(html_file_path)
print(f"Saved figure: {html_file_path}")
# Out:
# Using cleaned DataFrame with 14299 rows.
# Saved figure: Interactive_cluster_map_study_design_type_plot_final.html
